# %%
using Pkg
Pkg.activate("./..")
Pkg.add("Agents") # install Agents.jl if not installed
# Out:
#   Activating new project at `/workspaces/agentsjl/notebooks`
#    Resolving package versions...
#     Updating `/workspaces/agentsjl/notebooks/Project.toml`
#   [46ada45e] + Agents v5.17.2
#     Updating `/workspaces/agentsjl/notebooks/Manifest.toml`
#   [46ada45e] + Agents v5.17.2
#   [ec485272] + ArnoldiMethod v0.2.0
# ⌅ [1dc0ca97] + ArrayTools v0.2.7
#   [d1d4a3ce] + BitFlags v0.1.8
#   [336ed68f] + CSV v0.10.12
#   [49dc2e85] + Calculus v0.5.1
#   [944b1d66] + CodecZlib v0.7.3
#   [38540f10] + CommonSolve v0.2.4
#   [34da2185] + Compat v4.12.0
#   [f0e56b4a] + ConcurrentUtilities v2.3.0
#   [a8cc5b0e] + Crayons v4.1.1
#   [9a962f9c] + DataAPI v1.16.0
#   [a93c6f00] + DataFrames v1.6.1
#   [864edb3b] + DataStructures v0.18.16
#   [e2d170a0] + DataValueInterfaces v1.0.0
#   [b4f34e82] + Distances v0.10.11
#   [31c24e10] + Distributions v0.25.107
#   [ffbed154] + DocStringExtensions v0.9.3
#   [fa6b7ba4] + DualNumbers v0.6.8
#   [460bff9d] + ExceptionUnwrapping v0.1.10
# ...

# %%
println("Hello, world!")
# Out:
# Hello, world!
